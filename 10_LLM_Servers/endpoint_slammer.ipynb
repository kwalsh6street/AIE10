# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# ## The classic tongue‑twister answer
#
# > **“A woodchuck would chuck as much wood as a woodchuck can throw, and for a ground‑hog that’s about 700 pounds of wood.”**
#
# That’s the line that keeps popping up in song, folklore and the occasional “Did you know?” fact sheet. 700 pounds (≈100 kg) is roughly the weight a single adult woodchuck could move if it were actually a lumber­jacking professional.
#
# ---
#
# ## A bit of reality check
#
# 1. **Woodchucks don’t chuck wood**
#    The animal that gives us this riddle is a *Marmota monax* (ground‑hog).  They’re burrowing rodents, not lumberjacks.  Their cheek pouches are made of fat‑filled cartilage, not a natural apparatus for tossing logs.
#
# 2. **Why 700 pounds?**
#    The number comes from a playful 1988 letter to the *New York State Fish & Game Bulletin* by wildlife biologist **Richard W. Thiel**.  He used the animal’s bite force (≈150 N) and estimated the volume and density of a typical piece of wood to arrive at a **rough estimate of 700 lb**—a round figure that sticks in the public imagination.
#
# 3. **Other estimates**
#    In the 21st century, researchers have used modern video‑analysis and animal‑behavior models to estimate that a woodchuck could move matrix‑thick logs of roughly **0.5 m³** in a single “chuck” (about 10–15 ft³).  That’s still far from the folklore figure, but the higher number is more about playful exaggeration than actual physics.
#
# ---
#
# ## A quick math remix
#
# If you want a practical, science‑based mental model, here’s a straight‑forward way to think about it:
#
# | Assumption | Value |
# |------------|-------|
# | Comfortable chuck length | 1.5 m (about 5 ft) |
# | Wood density (softwood) | 400 kg/m³ |
# | Volume stripped from ground‑hog cheek pouch (one “throw”) | 0.1 m³ |
#
# **Result:**
# 0.1 m³ × 400 kg/m³ ≈ 40 kg (≈90 lb) per attempt.
# If the woodchuck could chuck twice a day for a 4‑week month, that’s roughly 640 lb – still in the ballpark of the folklore figure.
#
# ---
#
# ## Bottom line
#
# - **Folklore answer**: *About 700 pounds* (or “as many trees as a single ground‑hog’s day requires”).
# - **Reality answer**: *Likely a handful of fallen twigs* – woodchucks are draftsmen, not lumberjacks.
#
# So, if you’re still humming “Woodchuck Walnut,” just remember the answer is *a bit of a joke* rather than a hard‑wired fact. Happy chucking!

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 4: I’m happy to help with “Request 4,” but I’ll need the text o...
# Response 21: The tongue-twister has been around for ages, and its answer ...
# Response 22: A classic answer puts it humorously: a woodchuck would chuck...
# Response 5: A classic riddle with no definitive answer—most say a woodch...
# Response 8: That famous tongue‑twister has a few popular “answers” that ...
# Response 12: Wood‑chuck hoarding theory suggests that a single, dedicated...
# Response 14: That old tongue‑twister never had a “real” answer—it's just ...
# Response 19: Ah, the age‑old woodland quandary! The truth is it’s less a ...
# Response 6: A classic answer to that tongue‑twister is:
#
# > “A woodchuck ...
# Response 24: A wood‑chuck isn’t exactly taking on a lumber‑jack’s workloa...
# Response 17: **Answer (Request 17)**
#
# The classic nursery‑tongue‑twiste...
# Response 16: **Answer:**
#
# The classic tongue‑twister “How much wood could...
# Response 2: The classic tongue‑twister goes:
#
# > *“How much wood could a ...
# Response 7: Who’s up for a classic tongue‑twister? 🤔
#
# **“How much wood c...
# Response 9: The classic tongue‑twister goes:
# > *How much wood would a ...
# Response 1: **Answer – The tongue‑twister’s “guess”**
#
# The classic tongu...
# Response 18: Ah, the age‑old tongue‑twister!  In pure rhyme‑logic, a wood...
# Response 23: It’s a classic riddle, not a literal biology problem, but th...
# Response 10: Here are **10 different takes** on the age‑old question “How...
# Response 13: It’s a classic tongue‑twister more than a physics problem, b...
# Response 20: Here are **20 playful ways** to answer the classic “wood‑chu...
# Response 15: **Short answer (the classic tongue‑twister)**
# A woodchuck ...
# Response 11: The classic answer to the tongue‑twister is usually playful ...
# Response 3: The question “How much wood could a wood‑chuck chuck if a wo...
